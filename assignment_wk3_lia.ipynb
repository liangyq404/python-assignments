# %% [markdown]
# ### Assignment: Poem (3 weeks)

# %%
divider = "***"
title = "Not my responsibility"
author = "Billie Eilish"

note = "The performance is scripted in the form of a voiceover"

key1 = "opinions"
key2 = "body"

my_dic = {'who': ['I', 'you', 'we'], 'do': ['hate', 'praise', 'shame', 'watch', 'decide', 'judge']}
body_parts = ['head','eyes', 'shoulders', 'chest', 'stomach', 'legs', 'feet']

#week 2: added a dancer and the dancer's movements is scriptied with voiceover

# print('\n')
# print(f'{divider}')
    
# print(f'{divider}')
# print('\n')


#week 3: added the inner activity of the audience
inner_activity = ["curious"]


print('\n')
print(f'{divider}')
    
def reflection ():
    
    for item in inner_activity:
        print(item)

print(f'{divider}')
print('\n')



performer = "The dancer"
my_string = "who do you think you are"
your_string = "to me"

def question():
    print(my_string.capitalize(), "?")

def shout():
    print(my_string.capitalize(), your_string.upper(), "?")

    


print(title.upper())
print('\n')
print(f'by {author}')
# print('\n')
# print(f'{divider}')
# print(f'{note}')
# print(f'{divider}')
print('\n')
print('Do you know me?')
print('Really know me?')
print(f'You have {key1}')
print(f'About my {key1}')
print('About my music')
print('About my clothes')
print(f'About my {key2}')

#five dancers enter the stage and one by one lights up the candle in their hands

print('\n')
print(f'{divider}')


for i in range(5):
    print (f'A dancer comes to stage')
    
print(f'{divider}')
print('\n')


print('\n')
print(f'{divider}')

candle = ["yellow candle", "red candle", "green candle", "purple candle", "white candle"]
for color in candle:
        print(color, "has been lighted")


print(f'{divider}')
print('\n')

print(f'Some people {my_dic["do"][0]} what {my_dic["who"][1]} wear')
print(f'Some people {my_dic["do"][1]} it')
print(f'Some people use it to {my_dic["do"][2]} others')
print(f'Some people use it to {my_dic["do"][2]} me')

print('\n')
print(f'But {my_dic["who"][0]} feel {my_dic["who"][1]} {my_dic["do"][3]}ing' )
print('Always')
print('And nothing I do goes unseen')
print(f'So while I feel your stares')
print('your disapproval')
print('or your sigh of relief')
print('if I lived by them')
print('I’d never be able to move')
print('\n')

print('would you like me to be smaller?')
print('Weaker?')
print('Softer?')
print('Taller?')
print('Would you like me to be quiet?')

inner_activity.append("sigh")

print('do my shoulders provoke you?')
print('does my chest?')
print('my hips?')
print('the body I was born with')
print('is it not what you wanted?')
print('\n')

print('\n')
print(f'{divider}')

print("the dancers have confused look on their face, they ask: ")
question()

inner_activity.append("touched")

print(f'{divider}')
print('\n')

print('if I wear what is comfortable')
print('I am not a woman')
print('if I shed the layers')
print('I’m a slut')
inner_activity.append("shock")
print('though you’ve never seen my body')
print('you still judge it')
print('and judge me for it')
print('why?')
inner_activity.append("agree")
print('\n')


print('\n')
print(f'{divider}')

print("the dancers have angry look on their face, they shout: ")
shout()

print(f'{divider}')
print('\n')

print('we make assumptions about people')
print('based on their size')
print('we decide who they are')
print('we decide what they’re worth')
print('if I wear more')
print('if I wear less')
print('who decides what that makes me?')
print('What that means?')
print('Is my value based only on your perception?')
print('Or is your opinion of me')
print(f'{title}')


print('\n')
print(f'{divider}')
    
x = 1
while x < 6:
    print(f'A dancer disappears')
    x += 1

print(f'{divider}')
print('\n')



print('\n')
print(f'{divider}')
    
magic = ["becomes fire", "becomes flower", "becomes woods", "becomes fungi", "becomes pearl"]
# candle = ["yellow candle", "red candle", "green candle", "purple candle", "white candle"]

y = 0
while y < 5:
    print("The", candle[y], magic[y])
    y += 1

print(f'{divider}')
print('\n')



print("In the end, the audience went through a journey of")
reflection()
# Out:
# ***
# ***
#
#
# NOT MY RESPONSIBILITY
#
#
# by Billie Eilish
#
#
# Do you know me?
# Really know me?
# You have opinions
# About my opinions
# About my music
# About my clothes
# About my body
#
#
# ***
# A dancer comes to stage
# A dancer comes to stage
# A dancer comes to stage
# A dancer comes to stage
# A dancer comes to stage
# ***
#
#
#
#
# ***
# yellow candle has been lighted
# red candle has been lighted
# green candle has been lighted
# purple candle has been lighted
# white candle has been lighted
# ***
#
#
# Some people hate what you wear
# Some people praise it
# Some people use it to shame others
# Some people use it to shame me
#
#
# But I feel you watching
# Always
# And nothing I do goes unseen
# So while I feel your stares
# your disapproval
# or your sigh of relief
# if I lived by them
# I’d never be able to move
#
#
# would you like me to be smaller?
# Weaker?
# Softer?
# Taller?
# Would you like me to be quiet?
# do my shoulders provoke you?
# does my chest?
# my hips?
# the body I was born with
# is it not what you wanted?
#
#
#
#
# ***
# the dancers have confused look on their face, they ask:
# Who do you think you are ?
# ***
#
#
# if I wear what is comfortable
# I am not a woman
# if I shed the layers
# I’m a slut
# though you’ve never seen my body
# you still judge it
# and judge me for it
# why?
#
#
#
#
# ***
# the dancers have angry look on their face, they shout:
# Who do you think you are TO ME ?
# ***
#
#
# we make assumptions about people
# based on their size
# we decide who they are
# we decide what they’re worth
# if I wear more
# if I wear less
# who decides what that makes me?
# What that means?
# Is my value based only on your perception?
# Or is your opinion of me
# Not my responsibility
#
#
# ***
# A dancer disappears
# A dancer disappears
# A dancer disappears
# A dancer disappears
# A dancer disappears
# ***
#
#
#
#
# ***
# The yellow candle becomes fire
# The red candle becomes flower
# The green candle becomes woods
# The purple candle becomes fungi
# The white candle becomes pearl
# ***
#
#
# In the end, the audience went through a journey of
# curious
# sigh
# touched
# shock
# agree
